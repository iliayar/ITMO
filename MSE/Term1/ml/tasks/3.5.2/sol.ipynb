# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
# %pip install -q ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.130 🚀 Python-3.12.12 torch-2.7.0 CPU (AMD Ryzen 9 7950X 16-Core Processor)
# Setup complete ✅ (32 CPUs, 61.9 GB RAM, 215.0/640.1 GB disk)

# %%
from ultralytics import YOLO
from PIL import Image

model = YOLO('yolo11n.pt')

# %%
img = '42'
results = model(f'./{img}.jpg', save=True, conf=0.8)
image = Image.open(f'runs/detect/predict2/{img}.jpg')
image
# Out:
# image 1/1 /home/iliayar/Repos/ITMO/MSE/Term1/ml/tasks/3.5.2/42.jpg: 448x640 4 persons, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x479>
